# %%
import pandas as pd

# %%
df = pd.read_csv(r'police_clean5.csv')

# %%
df = df.merge(pd.read_json(r'test.json')[['index','x1','y1']], on='index',how='left')

# %%
df = df.merge(pd.read_json(r'test2.json')[['index','x2','y2']], on='index',how='left')

# %%
df = df.merge(pd.read_json(r'test3.json')[['index','x3','y3']], on='index',how='left')

# %%
df[['x3','y3']]=df[['x3','y3']].fillna(2000)

# %%
df.to_csv(r'police_clean8.csv')

# %%
df[df['City'] == 'Portland, OR, USA']
# Out:
#      Unnamed: 0  index               City Upload Date\n (MM/DD/YYYY)  \
# 186         186    186  Portland, OR, USA                 06/03/2020
# 188         188    188  Portland, OR, USA                 06/03/2020
# 190         190    190  Portland, OR, USA                 06/03/2020
# 193         193    193  Portland, OR, USA                 06/03/2020
# 194         194    194  Portland, OR, USA                 06/03/2020
# 246         246    246  Portland, OR, USA                 06/06/2020
# 247         247    247  Portland, OR, USA                 06/06/2020
# 248         248    248  Portland, OR, USA                 06/06/2020
# 253         253    253  Portland, OR, USA                 06/07/2020
# 258         258    258  Portland, OR, USA                 06/08/2020
# 269         269    269  Portland, OR, USA                 06/14/2020
# 272         272    272  Portland, OR, USA                 06/15/2020
# 285         285    285  Portland, OR, USA                 06/16/2020
# ...

# %%
df[df['City'] == 'Portland, OR, USA']
# Out:
#      Unnamed: 0  index               City Upload Date\n (MM/DD/YYYY)  \
# 186         186    186  Portland, OR, USA                 06/03/2020
# 188         188    188  Portland, OR, USA                 06/03/2020
# 190         190    190  Portland, OR, USA                 06/03/2020
# 193         193    193  Portland, OR, USA                 06/03/2020
# 194         194    194  Portland, OR, USA                 06/03/2020
# 246         246    246  Portland, OR, USA                 06/06/2020
# 247         247    247  Portland, OR, USA                 06/06/2020
# 248         248    248  Portland, OR, USA                 06/06/2020
# 253         253    253  Portland, OR, USA                 06/07/2020
# 258         258    258  Portland, OR, USA                 06/08/2020
# 269         269    269  Portland, OR, USA                 06/14/2020
# 272         272    272  Portland, OR, USA                 06/15/2020
# 285         285    285  Portland, OR, USA                 06/16/2020
# ...
